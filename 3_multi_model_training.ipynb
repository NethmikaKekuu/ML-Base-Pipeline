# %%
import joblib
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import(
    StratifiedGroupKFold,
    cross_validate
)
warnings.filterwarnings('ignore')

# %% [markdown]
# 1. Load the Data

# %%
X_train = np.load('artifacts/X_train.npz')['arr_0']
Y_train = np.load('artifacts/Y_train.npz')['arr_0']
X_test = np.load('artifacts/X_test.npz')['arr_0']
Y_test = np.load('artifacts/Y_test.npz')['arr_0']

# %% [markdown]
# 2. Define Multi Models

# %%
models = {
    'Logistic Regression' : LogisticRegression(),
    'Decision Tree' : DecisionTreeClassifier(),
    'Random Forest' : RandomForestClassifier()
}

# %% [markdown]
# 3. Configure K-Fold CV

# %%
cv = StratifiedGroupKFold(
    n_splits=6,
    random_state=42,
    shuffle=True
)

# %%
for model_name, model in models.items():
    print(f"\nCross Validation on {model_name}")

    cv_results = cross_validate(
        model,
        X_train, 
        Y_train.values.ravel(),  
        scoring='f1',
        return_estimator=True,
        return_train_score=False
    )

    test_scores = cv_results['test_score']
    best_index = np.argmax(test_scores)
# Out:
# Cross Validation on Logistic Regression
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 4
#       1 for model_name, model in models.items():
#       2     print(f"\nCross Validation on {model_name}")
# ----> 4     cv_results = cross_validate(
#       5         model,
#       6         X_train, Y_train,
#       7         cv=cv,
#       8         scoring='f1',
#       9         return_estimator=True,
#      10         return_train_score=False
#      11     )
#      13     test_scores = cv_results['test_score']
#      14     best_index = np.argmax(test_scores)
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\model_selection\_validation.py:373, in cross_validate(estimator, X, y, groups, scoring, cv, n_jobs, verbose, params, pre_dispatch, return_train_score, return_estimator, return_indices, error_score)
#     370 # We clone the estimator to make sure that all the folds are
#     371 # independent, and that it is pickle-able.
#     372 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 373 results = parallel(
#     374     delayed(_fit_and_score)(
#     375         clone(estimator),
#     376         X,
#     377         y,
#     378         scorer=scorers,
#     379         train=train,
#     380         test=test,
#     381         verbose=verbose,
#     382         parameters=None,
#     383         fit_params=routed_params.estimator.fit,
#     384         score_params=routed_params.scorer.score,
#     385         return_train_score=return_train_score,
#     386         return_times=True,
#     387         return_estimator=return_estimator,
#     388         error_score=error_score,
#     389     )
#     390     for train, test in indices
#     391 )
#     393 _warn_or_raise_about_fit_failures(results, error_score)
#     395 # For callable scoring, the return type is only know after calling. If the
#     396 # return type is a dictionary, the error scores can now be inserted with
#     397 # the correct key.
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\utils\parallel.py:91, in Parallel.__call__(self, iterable)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
#      83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#    (...)     89     for delayed_func, args, kwargs in iterable
#      90 )
# ---> 91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\joblib\parallel.py:1986, in Parallel.__call__(self, iterable)
#    1984     output = self._get_sequential_output(iterable)
#    1985     next(output)
# -> 1986     return output if self.return_generator else list(output)
#    1988 # Let's create an ID that uniquely identifies the current call. If the
#    1989 # call is interrupted early and that the same instance is immediately
#    1990 # reused, this id will be used to prevent workers that were
#    1991 # concurrently finalizing a task from the previous call to run the
#    1992 # callback.
#    1993 with self._lock:
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\joblib\parallel.py:1911, in Parallel._get_sequential_output(self, iterable)
#    1908 yield None
#    1910 # Sequentially call the tasks and yield the results.
# -> 1911 for func, args, kwargs in iterable:
#    1912     self.n_dispatched_batches += 1
#    1913     self.n_dispatched_tasks += 1
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\utils\parallel.py:83, in <genexpr>(.0)
#      78 filters_func = getattr(warnings, "_get_filters", None)
#      79 warning_filters = (
#      80     filters_func() if filters_func is not None else warnings.filters
#      81 )
# ---> 83 iterable_with_config_and_warning_filters = (
#      84     (
#      85         _with_config_and_warning_filters(delayed_func, config, warning_filters),
#      86         args,
#      87         kwargs,
#      88     )
#      89     for delayed_func, args, kwargs in iterable
#      90 )
#      91 return super().__call__(iterable_with_config_and_warning_filters)
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\model_selection\_validation.py:373, in <genexpr>(.0)
#     370 # We clone the estimator to make sure that all the folds are
#     371 # independent, and that it is pickle-able.
#     372 parallel = Parallel(n_jobs=n_jobs, verbose=verbose, pre_dispatch=pre_dispatch)
# --> 373 results = parallel(
#     374     delayed(_fit_and_score)(
#     375         clone(estimator),
#     376         X,
#     377         y,
#     378         scorer=scorers,
#     379         train=train,
#     380         test=test,
#     381         verbose=verbose,
#     382         parameters=None,
#     383         fit_params=routed_params.estimator.fit,
#     384         score_params=routed_params.scorer.score,
#     385         return_train_score=return_train_score,
#     386         return_times=True,
#     387         return_estimator=return_estimator,
#     388         error_score=error_score,
#     389     )
#     390     for train, test in indices
#     391 )
#     393 _warn_or_raise_about_fit_failures(results, error_score)
#     395 # For callable scoring, the return type is only know after calling. If the
#     396 # return type is a dictionary, the error scores can now be inserted with
#     397 # the correct key.
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\model_selection\_split.py:412, in _BaseKFold.split(self, X, y, groups)
#     404 if self.n_splits > n_samples:
#     405     raise ValueError(
#     406         (
#     407             "Cannot have number of splits n_splits={0} greater"
#     408             " than the number of samples: n_samples={1}."
#     409         ).format(self.n_splits, n_samples)
#     410     )
# --> 412 for train, test in super().split(X, y, groups):
#     413     yield train, test
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\model_selection\_split.py:143, in BaseCrossValidator.split(self, X, y, groups)
#     141 X, y, groups = indexable(X, y, groups)
#     142 indices = np.arange(_num_samples(X))
# --> 143 for test_index in self._iter_test_masks(X, y, groups):
#     144     train_index = indices[np.logical_not(test_index)]
#     145     test_index = indices[test_index]
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\model_selection\_split.py:155, in BaseCrossValidator._iter_test_masks(self, X, y, groups)
#     150 def _iter_test_masks(self, X=None, y=None, groups=None):
#     151     """Generates boolean masks corresponding to test sets.
#     152
#     153     By default, delegates to _iter_test_indices(X, y, groups)
#     154     """
# --> 155     for test_index in self._iter_test_indices(X, y, groups):
#     156         test_mask = np.zeros(_num_samples(X), dtype=bool)
#     157         test_mask[test_index] = True
#
# File c:\Users\nethm\anaconda3\envs\bprmls\Lib\site-packages\sklearn\model_selection\_split.py:1049, in StratifiedGroupKFold._iter_test_indices(self, X, y, groups)
#    1045 _, groups_inv, groups_cnt = np.unique(
#    1046     groups, return_inverse=True, return_counts=True
#    1047 )
#    1048 y_counts_per_group = np.zeros((len(groups_cnt), n_classes))
# -> 1049 for class_idx, group_idx in zip(y_inv, groups_inv):
#    1050     y_counts_per_group[group_idx, class_idx] += 1
#    1052 y_counts_per_fold = np.zeros((self.n_splits, n_classes))
#
# TypeError: iteration over a 0-d array
